# %%
pip show pyabsa
# Out:
# Name: pyabsa
# Version: 2.4.1.post1
# Summary: This tool provides the state-of-the-art models for aspect term extraction (ATE), aspect polarity classification (APC), and text classification (TC).
# Home-page: https://github.com/yangheng95/PyABSA
# Author: Yang, Heng
# Author-email: hy345@exeter.ac.uk
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages
# Requires: autocuda, boostaug, findfile, gitpython, metric-visualizer, networkx, pandas, protobuf, pytorch-warmup, sentencepiece, seqeval, spacy, termcolor, torch, tqdm, transformers, typing-extensions, update-checker
# Required-by: boostaug
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import Counter
from pyabsa import AspectTermExtraction as ATEPC, available_checkpoints
from sqlalchemy import create_engine, text
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
print("SpaCy model loaded successfully!")
# Out:
# SpaCy model loaded successfully!

# %% [markdown]
# ### Helper functions

# %%
# Pre processing functions
def rid_numbers_punct(df):
    def clean_text(text):
        # Ensure the input is a string
        text = str(text) if text is not None else ""
        # Remove numbers and punctuation, except essential ones like periods for sentence structure
        return re.sub(r'[^\w\s]', '', text)  # Keep only alphanumeric and spaces
    
    # Apply the cleaning function
    df['review_text'] = df['review_text'].astype(str).apply(clean_text)
    return df


# Function to transform all sentences to lowercase
def lowercase(df):
    df['review_text'] = df['review_text'].str.lower()
    return df

def blank_lines_reduction(df):
    df['review_text'].replace('', np.nan, inplace=True)
    return df

# Function to remove stopwords
def exclude_stopwords(df):
    stop_words = set(stopwords.words('english'))
    def remove_stopwords(text):
        tokens = word_tokenize(text)
        return ' '.join([word for word in tokens if word not in stop_words])
    df['review_text'] = df['review_text'].apply(remove_stopwords)
    return df

# Function to remove words with fewer than three characters
def remove_under_three_characters(df):
    def remove_short_words(text):
        return ' '.join([word for word in text if len(word) >= 3])
    df['review_text'] = df['review_text'].apply(remove_short_words)
    return df

# Function to tokenize the text
def tokenize(df):
    df['review_text'] = df['review_text'].apply(word_tokenize)
    return df

# Stemming function
def stemming(df):
    stemmer = PorterStemmer()
    def stem_text(tokens):
        return [stemmer.stem(word) for word in tokens]
    df['review_text'] = df['review_text'].apply(lambda tokens: stem_text(tokens))
    return df

# Lemmatization function for words appearing in <1% of the corpus
def lemmatize_rare_words(df):
    lemmatizer = WordNetLemmatizer()
    
    # Flatten list of tokens to calculate word frequencies
    all_tokens = [word for tokens in df['review_text'] for word in tokens]
    word_freq = Counter(all_tokens)
    total_words = sum(word_freq.values())
    threshold = total_words * 0.01  # 1% threshold
    
    # Identify rare words
    rare_words = {word for word, freq in word_freq.items() if freq < threshold}
    
    def lemmatize_text(tokens):
        return [
            lemmatizer.lemmatize(word) if word in rare_words else word
            for word in tokens
        ]
    
    df['review_text'] = df['review_text'].apply(lambda tokens: lemmatize_text(tokens))
    return df

# %%
# Minimal preprocessing function
def minimal_preprocessing(df):
    def clean_text(text):
        # Ensure the input is a string
        text = str(text) if text is not None else ""
        # Remove URLs
        text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)
        # Remove special characters, keeping basic punctuation
        text = re.sub(r"[^a-zA-Z0-9\s.,!?']+", "", text)
        # Normalize whitespace
        text = re.sub(r"\s+", " ", text).strip()
        return text

    # Apply minimal cleaning
    df['review_text'] = df['review_text'].apply(clean_text)
    return df

# %%
# Load absa model and test it out
def load_and_apply_absa_model(df):
    aspect_extractor = ATEPC.AspectExtractor('multilingual',
                                        auto_device=True,  # False means load model on CPU
                                        cal_perplexity=True,
                                        )
    
    # Apply model
    def apply_model(text):
        processed_text = aspect_extractor.predict(text, ignore_error = True)
        return processed_text

    df['predicted_text'] = df['review_text'].apply(apply_model)
    return df

# %%
# Example pipeline for preprocessing what choices actually to apply
def preprocess_pipeline(df):
    df = minimal_preprocessing(df)
    return df

# %%
def extract_aspects_sentiments(row):
    """
    Extracts aspect terms and sentiments from PyABSA predictions.

    Args:
        row (dict): A dictionary containing the predicted text output from PyABSA.

    Returns:
        tuple: (aspect_terms, sentiment_terms) as comma-separated strings.
    """
    if isinstance(row, dict) and 'aspect' in row and 'sentiment' in row:
        aspect_terms = ", ".join(row['aspect']) if row['aspect'] else ""
        sentiment_terms = ", ".join(row['sentiment']) if row['sentiment'] else ""
        return aspect_terms, sentiment_terms
    return "", ""

# %% [markdown]
# ### End of helper functions

# %%
### Connection to the database
engine = create_engine('postgresql+psycopg2://patrickstewart:password@localhost:5432/patrickstewart')

# %%
try:
    # Establish a connection
    with engine.connect() as connection:
        # Query to extract the 'product_info' table
        product_info_query = "SELECT * FROM product_info"
        product_info_df = pd.read_sql_query(text(product_info_query), connection)
        print("Product Info Table extracted successfully.")

        # Query to extract the 'product_reviews' table
        product_reviews_query = "SELECT * FROM product_reviews"
        product_reviews_df = pd.read_sql_query(text(product_reviews_query), connection)
        print("Product Reviews Table extracted successfully.")

    # Display the first few rows of each DataFrame to confirm
    print("\nProduct Info DataFrame:\n", product_info_df.head())
    print("\nProduct Reviews DataFrame:\n", product_reviews_df.head())
except Exception as e:
    print("Error:", e)
# Out:
# Error: 'str' object is not callable

# %%
### Let's just select the data most important and keep that as the demo - just the table product_reviews is fine

# %%
### Apply processing function
# Rid blank lines seen in the function
product_reviews_df_process =  preprocess_pipeline(product_reviews_df)

# %%
product_reviews_df_process =  load_and_apply_absa_model(product_reviews_df.head(100))
# Out:
# [2025-01-31 16:21:14] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2025-01-31 16:21:14] (2.4.1.post1) ********** Available ATEPC model checkpoints for Version:2.4.1.post1 (this version) **********
# [2025-01-31 16:21:14] (2.4.1.post1) Downloading checkpoint:multilingual
# [2025-01-31 16:21:14] (2.4.1.post1) Notice: The pretrained model are used for testing, it is recommended to train the model on your own custom datasets
# [2025-01-31 16:21:14] (2.4.1.post1) Checkpoint already downloaded, skip
# [2025-01-31 16:21:14] (2.4.1.post1) Load aspect extractor from checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT
# [2025-01-31 16:21:14] (2.4.1.post1) config: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config
# [2025-01-31 16:21:14] (2.4.1.post1) state_dict: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.state_dict
# [2025-01-31 16:21:14] (2.4.1.post1) model: None
# [2025-01-31 16:21:14] (2.4.1.post1) tokenizer: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.tokenizer
# [2025-01-31 16:21:14] (2.4.1.post1) Set Model Device: cpu
# [2025-01-31 16:21:14] (2.4.1.post1) Device Name: Unknown
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:102: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# [2025-01-31 16:21:33] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:33] (2.4.1.post1) Example 0: I use this with the Nudestix Citrus <Clean Balm:Positive Confidence:0.9715> MakeUp <Melt:Positive Confidence:0.974> to double cleanse and it has completely changed my skin for the better . The <makeup melt:Positive Confidence:0.8979> is oil based and removes all of your makeup super easily . I followup with this water based cleanser , and I also use this just by itself when Im not wearing makeup . It leaves the skin gently cleansed , but without stripping the skin . 1010 recommend combining with the makeup melt . Its perfection !
# [2025-01-31 16:21:34] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:34] (2.4.1.post1) Example 0: I bought this <lip:Negative Confidence:0.6286> mask after reading the reviews and the hype . Unfortunately , it did not meet my expectations as vaseline petroleum <jelly:Positive Confidence:0.8776> works way better for me .
# [2025-01-31 16:21:34] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:34] (2.4.1.post1) Example 0: My review title says it all ! I get so excited to get into bed and apply this <lip mask:Positive Confidence:0.7662> . I do see a difference because I suffer from dry cracked lips . I drink a lot of water and apply lip balm daily but nothing helped until I started using this . untiluntistafted usinf this .
# [2025-01-31 16:21:35] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:35] (2.4.1.post1) Example 0: Ive always loved this <formula:Positive Confidence:0.946> for a long time . I honestly dont even use it for night time . I use it as an everyday lip balm . I love the texture . Gummy Bear is my second most favourite scent . <Grapefruit:Positive Confidence:0.922> is the best in my opinion .
# [2025-01-31 16:21:36] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:36] (2.4.1.post1) Example 0: If you have dry cracked lips , this is a must have . After a few weeks of use I have learned I will always have by my bedside . I thought it was a little expensive but a little goes a long way . It is worth the <price:Positive Confidence:0.8144> .
# [2025-01-31 16:21:37] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:37] (2.4.1.post1) Example 0: The <scent:Positive Confidence:0.5025> isnt my favourite but it works great ! I put it on every night before I go to sleep and every morning I wake up with smooth , moisturizer and soft . <Packaging:Positive Confidence:0.9958> is amazing as well
# [2025-01-31 16:21:37] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:37] (2.4.1.post1) Example 0: Ill give this 2 stars for nice <packaging:Positive Confidence:0.7421> and lovely <scent:Positive Confidence:0.8764> . Upon initial application , it feels very nice . But as I continued to use it I noticed I was getting more and more blackheadsclogged pores and pimples around my lips . I thought it was my Aquaphor but its THIS ! ! ! ! It also makes my lips even more dry than they initially were . Disappointing around my
# [2025-01-31 16:21:38] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:38] (2.4.1.post1) Example 0: I use this at night or while Im putting <makeup:Neutral Confidence:0.7315> on . Love the way I dont have to reapply it during the night . Definitely a win .
# [2025-01-31 16:21:39] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:39] (2.4.1.post1) Example 0: I love this stuff . I first had the sample size from a Sephora Birthday gift , and once I had run through it I knew it was a purchase . I live in an incredibly dry <environment:Negative Confidence:0.7814> , great for <macarons:Negative Confidence:0.6556> , but terrible for my skin . This lip mask helps to keep my lips from becoming too chapped .
# [2025-01-31 16:21:40] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:40] (2.4.1.post1) Example 0: I purchased the <Sweet Candy scent:Positive Confidence:0.9321> at my local Sephora and I am OBSESSED ! ! I will be honest , the scent is a bit strong but theyre all strongly scented . My lips are so soft . 1010 !
# [2025-01-31 16:21:41] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:41] (2.4.1.post1) Example 0: this product is a bit pricey but after using one scoop i figured this will take a LONG time to use up the whole <container:Positive Confidence:0.8564> . it <smells:Positive Confidence:0.9514> so good and the container is so cute .
# [2025-01-31 16:21:42] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:42] (2.4.1.post1) Example 0: I use this every night and morning and it works wonders ! This never fails to make my lips super hydrated ! The <tint:Positive Confidence:0.9978> and shine to it makes it even a great lip gloss during the day !
# [2025-01-31 16:21:42] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:42] (2.4.1.post1) Example 0: A little goes a long way . Love the <fragrance:Positive Confidence:0.9692> and works great as a night lip <mask:Positive Confidence:0.8981> . Only reason I gave it 4 stars is because of the <price:Negative Confidence:0.862> .
# [2025-01-31 16:21:43] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:43] (2.4.1.post1) Example 0: Honestly I was so excited when I got this in the mail . But unfortunately it is not worth the hype I have boughten two of these full size and I went through them so quickly . The <ingredients:Negative Confidence:0.9746> are not very clean and this product made my lips so dry . I wanted to like this product so bad as its so cute and smells nice . But unfortunately it is a hard pass for me . I will be sticking to my vaseline and aquaphor for now
# [2025-01-31 16:21:44] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:44] (2.4.1.post1) Example 0: Does the <gummy bear mask:Positive Confidence:0.9803> smell absolutely delicious ? ! Yes . Does it do much for my lips overnight ? Nope . They are dry and a little chapped in the morning . I honestly have better luck with my vaseline lip therapy but I am still keeping the <Laneige:Positive Confidence:0.6666> to use as a daily balm .
# [2025-01-31 16:21:45] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:45] (2.4.1.post1) Example 0: I just got this a few days ago , its amazing ! I love the berry <scent:Positive Confidence:0.9977> ! Its very hydrating and my lips are so smooth and glossy . My lips are always chapped and dry this has really helped !
# [2025-01-31 16:21:46] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:46] (2.4.1.post1) Example 0: i love how hydrating this makes my lips feel ! perfect for an overnight lip <mask:Positive Confidence:0.9007> or just a <gloss:Positive Confidence:0.9387> as well ! lasts forever
# [2025-01-31 16:21:46] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:46] (2.4.1.post1) Example 0: Its super glossy and looks amazing but doesnt last very long after use .
# [2025-01-31 16:21:47] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:47] (2.4.1.post1) Example 0: i have used this for about almost a year , and my <lips:Positive Confidence:0.9934> are so soft once i use this ! not only do i use it at night , but just when i need a quick moisturizing pick up for my lips
# [2025-01-31 16:21:48] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:48] (2.4.1.post1) Example 0: I have this in every colour except for sweet candy which will be my next purchase but I got the kit with the 5 <minis:Positive Confidence:0.8253> for christmas and I honestly love these so much , I wake up and my lips are instantly smooth , I can also use it as a lipgloss and its honestly my favourite lip product ever .
# [2025-01-31 16:21:49] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:49] (2.4.1.post1) Example 0: Theres nothing wrong with it but i think it was overhyped on tiktok . It actually made my <lips:Negative Confidence:0.9851> a little dry .
# [2025-01-31 16:21:49] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:49] (2.4.1.post1) Example 0: Just like Aquaphor just get something cheaper its just overrated . Its good but they also animal test .
# [2025-01-31 16:21:50] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:50] (2.4.1.post1) Example 0: I just started using it but from the first night my <lips:Positive Confidence:0.9911> felt way better . The next morning they even looked fuller which Im not sure if thats the intention but still ! And the <berry smell:Positive Confidence:0.9961> is so good !
# [2025-01-31 16:21:51] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:51] (2.4.1.post1) Example 0: This <lip balm:Positive Confidence:0.9982> is the best I ever had . It works . It hydrates and last long . It has everything you need in a balm . It even has a little spatula that you can use to scoop the product easily and cleanly .
# [2025-01-31 16:21:52] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:52] (2.4.1.post1) Example 0: Not worth the hype . My lips are still dry after using this product nightly , had much better results with the Ilia Lip Wrap , and its a cleaner product .
# [2025-01-31 16:21:52] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:52] (2.4.1.post1) Example 0: Super hydrating and <smells:Positive Confidence:0.9955> really good unlike certain lip masks
# [2025-01-31 16:21:53] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:53] (2.4.1.post1) Example 0: i love this product ! ! it leaves my lips so hydrated and the <colour:Positive Confidence:0.9985> is immaculate
# [2025-01-31 16:21:54] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:54] (2.4.1.post1) Example 0: i really tried to love this i wore it to sleep every night for a month but every time i woke up with lips chapped and peeling . overhyped and not worth the <money:Negative Confidence:0.853> just use vasaline
# [2025-01-31 16:21:55] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:55] (2.4.1.post1) Example 0: Love this ! ! ! Im obsessed with the Gummy bear scent . This stuff is so thick and creamy . Lasts for hours . Very hydrating . Loved it so much I bought the daytime gloss ! <Candy:Positive Confidence:0.9923> also smells amazing ! ! !
# [2025-01-31 16:21:55] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:55] (2.4.1.post1) Example 0: I love this <lippyit:Positive Confidence:0.9972> makes my lips soft and also is helping my acne scars to fake and no idea why ! !
# [2025-01-31 16:21:56] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:56] (2.4.1.post1) Example 0: dried my <lips:Negative Confidence:0.9946> out sooooooo bad . literally were cracked , peeling , and bleeding . I stopped using it and it got better . def do not recommend buying this
# [2025-01-31 16:21:57] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:57] (2.4.1.post1) Example 0: I used this product daily last week , and my <lips:Negative Confidence:0.9871> hurt . I stopped using it and just used <Aquaphor:Negative Confidence:0.6857> to heal them , and they are doing much better . I might be allergic to this product .
# [2025-01-31 16:21:57] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:57] (2.4.1.post1) Example 0: I really loved this product and did use the whole thing , it lasted over 6 months and I thought did a decent job . The only problem is that I noticed part of my lip started to get super dry and no matter how much I used , how frequently I reapplied , exfoliated my lips , it did not get better . Nothing else in my routine changed except for adding this product in so this did cause my lips to dry out and didnt fix it . Its not worth the price , Vaseline works just as good and never dried my lips out .
# [2025-01-31 16:21:58] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:58] (2.4.1.post1) Example 0: This product is amazing ! I use it before bed , and also throughout the day as a lip <balm:Positive Confidence:0.9241> . Its so smooth and feels amazing ! It doesnt have a sticky feeling at all . My lips are soft and smooth since adding this my routine . I will definitively be purchasing again .
# [2025-01-31 16:21:59] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:21:59] (2.4.1.post1) Example 0: In my opinion its very over hyped . Its not very moisturizing I prefer Tarte Jelly Glaze over this and its also half the <price:Positive Confidence:0.7415> which is the whole point . Its not horrible but its not good either . Plus Im pretty sure they test on animals so that doesnt make me appealed to buy again .
# [2025-01-31 16:22:00] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:00] (2.4.1.post1) Example 0: I almost want to wear this all day long . Its so tasty and so pretty when its on . The only reason I didnt give it a 5 star is because it doesnt really stay on long enough . Definitely not all night long .
# [2025-01-31 16:22:00] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:00] (2.4.1.post1) Example 0: It is so moisturizing and keeps my <lips:Positive Confidence:0.9974> super soft and hydrated .
# [2025-01-31 16:22:01] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:01] (2.4.1.post1) Example 0: I am super impressed with this <lip mask:Positive Confidence:0.9908> . I use it at bedtime and wake up with soft lips ! I struggle with cracked and peeling lips every winter I also use it on top of my lip liner in the morning for a plumped , soft look .
# [2025-01-31 16:22:02] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:02] (2.4.1.post1) Example 0: I used to like this product until I found out it has <BHT:Negative Confidence:0.9841> in it which is HAZARDOUS . Please do your research on the <ingredients:Negative Confidence:0.5852> and youll see this is horrible for you and your body especially if ingested .
# [2025-01-31 16:22:03] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:03] (2.4.1.post1) Example 0: love this so much ! I use it everyone night and it keeps my <lips:Positive Confidence:0.9761> so hydrated because they used to always be so dry and chapped ! 5 stars , 100 recommend !
# [2025-01-31 16:22:03] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:03] (2.4.1.post1) Example 0: Obsessed with this ! The first few days I wasnt seeing ton of results but after using it consistently for a bit my lips are no longer chapped . I dont have to reapply chapstick throughout the day . My lips also look fuller ! Wasnt excited about the <price:Positive Confidence:0.8714> but a small amount works well .
# [2025-01-31 16:22:04] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:04] (2.4.1.post1) Example 0: Ive been using for a couple months now and it seems great when you first apply however Ive seen no improvement in the long run . <Luis:Negative Confidence:0.9575> are still dry and peeling .
# [2025-01-31 16:22:05] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:05] (2.4.1.post1) Example 0: I wanted to love this product so bad because of all the amazing reviews but it honestly makes my <lips:Negative Confidence:0.9723> so disgustingly chapped . Ive used other <lip:Negative Confidence:0.9728> masks that this hasnt happened with and went back to try the <laniege:Negative Confidence:0.8208> one again and it gave me chapped lips again
# [2025-01-31 16:22:06] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:06] (2.4.1.post1) Example 0: Ive never used this kind of product , I tend to be very minimalist . After 1 night , I was already so impressed I had it mailed to a girlfriend as a gift . as far as <scents:Negative Confidence:0.9124> go , if youre shopping online all of the other ones are strong smells , it all smells like 90s chapstick . This one is milder , easier to go to sleep next to someone imho
# [2025-01-31 16:22:06] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:06] (2.4.1.post1) Example 0: Dont waste your money . I had gotten this as a sample , and used it as the directions said , it was very hydrating but overnight my lips were still dry . . . itd supposed to hydrate my lips overnight . Maybe Im just wrong
# [2025-01-31 16:22:07] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:07] (2.4.1.post1) Example 0: ive tried my friends a few times and it does good and smell nice but there are definitely dupes like the burts bee lip treatment that are much cheaper and as good
# [2025-01-31 16:22:08] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:08] (2.4.1.post1) Example 0: My <lips:Negative Confidence:0.9619> were always so dry but this product made them so soft and hydrated . I put it on at night but also during the day over a lip tint . Love it !
# [2025-01-31 16:22:08] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:08] (2.4.1.post1) Example 0: It works , makes my <lips:Positive Confidence:0.9786> soft so I dont need to use chapstick throughout the day . Sometimes I use it as lipgloss instead of a night mask .
# [2025-01-31 16:22:09] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:09] (2.4.1.post1) Example 0: Literally love all of Laneige products . The <lip sleeping mask:Positive Confidence:0.9901> has an amazing slip and its just the perfect overnight mask . Not sticky at all .
# [2025-01-31 16:22:10] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:10] (2.4.1.post1) Example 0: Ive had this <lip sleeping mask:Positive Confidence:0.993> for over a year now and it is the best overnight lip mask . When applied to my lips , it feels super soft and does not feel sticky . When I wake up , my lips are super soft and smooth . 1010 get it now .
# [2025-01-31 16:22:10] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:10] (2.4.1.post1) Example 0: So good . I love the <smell:Positive Confidence:0.994> and I bought 3 times to use this product , we can use this <lip:Positive Confidence:0.5801> sleeping mask in half a year , it is not expensive for 0 . 70 .
# [2025-01-31 16:22:11] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:11] (2.4.1.post1) Example 0: Amazing ! ! ! My lips literally react so badly to every single lip balm or chapstick . I had a allergic reaction to <jack black spf lip balm:Negative Confidence:0.5341> and this saved my lips ! ! They are super soft and moisturized
# [2025-01-31 16:22:12] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:12] (2.4.1.post1) Example 0: I use this every single night right before I go to bed and it leaves my <lips:Positive Confidence:0.9504> super smooth in the morning !
# [2025-01-31 16:22:13] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:13] (2.4.1.post1) Example 0: I have these in vanilla and sweet candy . I use them every day , multiple times a day . They hydrate much better than standard lip balms , and they last forever . Ive definitely had them for over a yearthey they dont change in consistency or effectiveness .
# [2025-01-31 16:22:13] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:13] (2.4.1.post1) Example 0: This product is amazing . It really does smell likes gummy bears and leaves the best moisturizing <feeling:Positive Confidence:0.9642> for a period of time . Stays shiny like a gloss
# [2025-01-31 16:22:14] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:14] (2.4.1.post1) Example 0: Excellent night facial moisturizer .
# [2025-01-31 16:22:15] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:15] (2.4.1.post1) Example 0: This product is marketed as a sleeping mask but i would say its more of a lip balm . It doesnt hydrate at all so dont turn to this looking to help dry lips . It doesnt last long at all . But it does look pretty on the lips , is not sticky , and has a really nice buttery <texture:Positive Confidence:0.5275> . Just wish that wasnt the only upside !
# [2025-01-31 16:22:15] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:15] (2.4.1.post1) Example 0: This <product:Positive Confidence:0.9968> is a DEFINITE must for chapped lips ! I get really chapped lips when Im stressed out , especially in the winter and it saved my life !
# [2025-01-31 16:22:16] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:16] (2.4.1.post1) Example 0: Love it ! ! ! ! Use it every night and it keeps my lips juicy throughout the whole day even in winter storms canada . Highly recommend it <tastes:Positive Confidence:0.9871> great too
# [2025-01-31 16:22:17] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:17] (2.4.1.post1) Example 0: Received this in the Sephora birthday pack . Wanted to love this strawberry scented lip <mask:Negative Confidence:0.9424> , but it didnt do much for me . Actually left my lips feeling a little drier . I fine almost any other lip balm works better .
# [2025-01-31 16:22:18] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:18] (2.4.1.post1) Example 0: after using this product for weeks it makes my <lips:Positive Confidence:0.9947> feel very nice and you dont really need a lot at a time so for the <price:Positive Confidence:0.9638> id say its worth it because u dont need to use that much it also doubles as a lipgloss !
# [2025-01-31 16:22:18] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:18] (2.4.1.post1) Example 0: Ive been using this for over 2 weeks now and its sooooo good . keeps my lips baby soft and it smells so nice and sweet too . 1010 recommend
# [2025-01-31 16:22:19] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:19] (2.4.1.post1) Example 0: It keeps my <lips:Positive Confidence:0.9958> so glossy hydrated ! ! ! You can use as <lip gloss:Neutral Confidence:0.677> if you want too
# [2025-01-31 16:22:20] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:20] (2.4.1.post1) Example 0: Je ne comprenais tellement pas pourquoi tout le monde se lanait sur ce produit jusqua ce que je lessaie moimme . Il hydrate tellement bien les lvre , il sent trop bon est nest pas dsagrable . Perso , je le porterais jour comme nuit , avec mes lvres sches , ce produit me donne limpression de renatre . En plus , il vient avec un petit applicateur , donc pas besoin davoir le doigt tout gras en prlvent dedans . Jadore ! Je ne pourrais plus men passer ! Il devrait toutes fois sortir plus dodeur qui sont plus douce .
# [2025-01-31 16:22:20] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:20] (2.4.1.post1) Example 0: love her ! as a <sleeping mask:Positive Confidence:0.9973> , i dont think you could ask for anything better
# [2025-01-31 16:22:21] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:21] (2.4.1.post1) Example 0: really not worth it to be honest . barely hydrates my lips . so expensive and not cruelty free . kinda worth it cause of <packaging:Negative Confidence:0.7109> . i was so hyped when i bought save ur money and buy some aquaphor instead
# [2025-01-31 16:22:22] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:22] (2.4.1.post1) Example 0: Amazing product for dry lips . It is a <mask:Positive Confidence:0.8134> , so you apply before bed then wipe excess in the morning . It smells so good you just wanna chew your lips offI wont of course lol . Great product for out of control dry lips like mine !
# [2025-01-31 16:22:23] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:23] (2.4.1.post1) Example 0: Really like this product for before bed . Its super hydrating and doesnt feel tacky . The <scents:Positive Confidence:0.9977> are great too !
# [2025-01-31 16:22:23] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:23] (2.4.1.post1) Example 0: This is now my second time purchasing this product . It is super hydrating , also nice to <wear:Positive Confidence:0.9731> during the day as well .
# [2025-01-31 16:22:24] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:24] (2.4.1.post1) Example 0: Within just a few days of using this <lip mask:Positive Confidence:0.9769> my dry lips from the cold dry winter feel so much better . Not overly greasy and easy to sleep with it on
# [2025-01-31 16:22:25] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:25] (2.4.1.post1) Example 0: Love this <lip masks:Positive Confidence:0.9962> so much I bought so many other flavours and if you have been thinking about getting it just buy it . It is literally so good . I would literally spend all my money on this . Im not joking its literally amazing .
# [2025-01-31 16:22:25] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:25] (2.4.1.post1) Example 0: I think this is overpriced for what it is <lip balm:Negative Confidence:0.5653> . It is nice though and when I apply it my lips feel nice . Definitely a luxury and not a need .
# [2025-01-31 16:22:26] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:26] (2.4.1.post1) Example 0: I love this product because it keeps by <lips:Positive Confidence:0.9938> really hydrated in the cold weather !
# [2025-01-31 16:22:27] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:27] (2.4.1.post1) Example 0: Received a sample and had to buy the full size immediately after I finished it . Ive used a lot of Blistex and other chapsticks , and I think this really helped heal my chapped lips . Definitely recommend !
# [2025-01-31 16:22:28] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:28] (2.4.1.post1) Example 0: I love this product so much I use it day and night . Its so hydrating and its like a lipgloss !
# [2025-01-31 16:22:28] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:28] (2.4.1.post1) Example 0: Love the <flavour:Positive Confidence:0.9974> et my lips are soft in the morning
# [2025-01-31 16:22:29] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:29] (2.4.1.post1) Example 0: I know this doesnt work for everyone but it sure works for me ! I use it at night and wake up to moisturized lips . A big caveat is that if Im not drinking water ie . that time I lost my water bottle for three days , there is no amount of lip balm that will fix my dry lips . Also , if you like the Japanese grape flavour , this is what the balm smells like exactly . Which in my case , is the perfect scenario . Not greasy or sticky and no flavour if you eat it . A little goes a long way imo so the price is a good deal for me .
# [2025-01-31 16:22:30] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:30] (2.4.1.post1) Example 0: Ive repurchased many times make sure to keep <spatula:Negative Confidence:0.5129> so you dont use your fingers so you dont get bacteria in it
# [2025-01-31 16:22:30] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:30] (2.4.1.post1) Example 0: I have a sample size of this product . It is very glossy and looks nice when first applied . Unfortunately , upon leaving it on overnight I found my <lips:Negative Confidence:0.8673> chapped in the morning and flaky .
# [2025-01-31 16:22:31] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:31] (2.4.1.post1) Example 0: This has really helped my dry lips especially in the winter . A must have in my routine !
# [2025-01-31 16:22:32] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:32] (2.4.1.post1) Example 0: Mes lvres sont beaucoup mieux hydrates aprs seulement 1 semaine d utilisation ! J ai essay un autre <masque de:Negative Confidence:0.6376> nuit avant celui la mais il ntait pas efficace ! En plus <Laneige:Positive Confidence:0.8372> sent super bon ! Lapp
# [2025-01-31 16:22:32] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:32] (2.4.1.post1) Example 0: not sticky , looks like gloss but feels like a lip balm or <butter:Positive Confidence:0.6721> . I hate sticky lip products and i love this . looks very pretty too .
# [2025-01-31 16:22:33] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:33] (2.4.1.post1) Example 0: I dont see the hype for this product . It doesnt work every time I use it , just once in a while . It gives my lips a nice glow and temporary hydration , but not as a treatment or for long term results . Would not repurchase
# [2025-01-31 16:22:34] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:34] (2.4.1.post1) Example 0: Didnt enjoy this product . I got it as a birthday gift . Ive only used it twice . Both times it dried out my lips badly that it took a week to get better . It left my lips more chapped than I began with was
# [2025-01-31 16:22:34] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:34] (2.4.1.post1) Example 0: This product smells good but that is basically the only good thing . The <lip mask:Negative Confidence:0.9395> feels like a weird bubble gum and looks identical to Vaseline when on your lips . Maybe if this product wasnt thirty dollars dollarsit would be worth it , but since its not I do not recommend it would be worth
# [2025-01-31 16:22:35] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:35] (2.4.1.post1) Example 0: I adore this product . It is perfect for any time of the day . I used to wear it only before I went to sleep , and it would make my lips so soft by the morning . Now I also use it as <lip gloss:Positive Confidence:0.7473> during the day . It makes my lips look very glossy and plump , similarly to when I wear the Dior lip oils .
# [2025-01-31 16:22:36] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:36] (2.4.1.post1) Example 0: Good product , feels nice on the lips . I wouldnt say that it is the most hydrating but it definitely looks good on the lips .
# [2025-01-31 16:22:37] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:37] (2.4.1.post1) Example 0: Hydrating and smells super yummy . Ill use this as a quick hydrator while Im doing makeup if I know Im putting on lipstick . This little jar will go a long way . Also love that it comes with an <applicator:Positive Confidence:0.9214> .
# [2025-01-31 16:22:37] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:37] (2.4.1.post1) Example 0: I took the <sweet candy:Negative Confidence:0.9943> one , I dont like it . Bought it 2 months ago , still have it .
# [2025-01-31 16:22:38] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:38] (2.4.1.post1) Example 0: my lips have been dry and flake for as long as i can remember . i finally got this and aquaphor and finally noticed a difference . in one night my lips were smooth and every since then have not flaked .
# [2025-01-31 16:22:39] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:39] (2.4.1.post1) Example 0: This product is so cute , especially with the little <applicator:Positive Confidence:0.996> for your lips . It keeps my lips hydrated really good , and I absolutely love this product .
# [2025-01-31 16:22:40] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:40] (2.4.1.post1) Example 0: I love the <feeling:Positive Confidence:0.9671> of all of lanieges lip masks and was so excited to try this one Yummy <candy:Positive Confidence:0.8724> but not too overpowering
# [2025-01-31 16:22:40] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:40] (2.4.1.post1) Example 0: I use this night and morning and LOVE it . This <tub:Positive Confidence:0.9979> lasts SO long too ! !
# [2025-01-31 16:22:41] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:41] (2.4.1.post1) Example 0: its good , i like it , it lives up to the hype . nothing more nothing less . also why tf are we spending 24 on <lip balm:Negative Confidence:0.6788> lol ? !
# [2025-01-31 16:22:42] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:42] (2.4.1.post1) Example 0: This product is AMAZING D
# [2025-01-31 16:22:42] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:42] (2.4.1.post1) Example 0: I love LANEIGE but i dont think this is worth 30 it is rlly good but i would wait for a sale or get it cheaper online
# [2025-01-31 16:22:43] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:43] (2.4.1.post1) Example 0: good for <use:Positive Confidence:0.997> all day not just for night made my <lips:Positive Confidence:0.9957> sooo soft
# [2025-01-31 16:22:44] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:44] (2.4.1.post1) Example 0: I love everything <laneige:Positive Confidence:0.9978> and this is no exception . Living in the Midwest in the winter this has literally SAVED my <lips:Positive Confidence:0.997> from being cracked and sore all winter !
# [2025-01-31 16:22:45] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:45] (2.4.1.post1) Example 0: Its the holy grail of lip hydration . I dont love the <applicator:Negative Confidence:0.9771> though and feel like it could easily be in a tube instead .
# [2025-01-31 16:22:45] (2.4.1.post1) The results of aspect term extraction have been saved in /Users/patrickstewart/Documents/Customer review platform/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2025-01-31 16:22:45] (2.4.1.post1) Example 0: its nice but buy the amazon dupe . Also the <application:Negative Confidence:0.9633> is a bit difficult . They have one with the squeeze tube thats better
# /var/folders/fp/d7xs_fxd4y74bcwbprt0zdsr0000gn/T/ipykernel_10963/2586964534.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicted_text'] = df['review_text'].apply(apply_model)

# %%
# Apply extraction to DataFrame
product_reviews_df_process[['aspect_terms', 'sentiments']] = product_reviews_df_process['predicted_text'].apply(
    lambda x: pd.Series(extract_aspects_sentiments(x))
)
# Out:
# /var/folders/fp/d7xs_fxd4y74bcwbprt0zdsr0000gn/T/ipykernel_10963/695199041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_reviews_df_process[['aspect_terms', 'sentiments']] = product_reviews_df_process['predicted_text'].apply(

# %%
product_reviews_df_process[['aspect_terms', 'sentiments']]
# Out:
#                      aspect_terms                    sentiments
# 0   Clean Balm, Melt, makeup melt  Positive, Positive, Positive
# 1                      lip, jelly            Negative, Positive
# 2                        lip mask                      Positive
# 3             formula, Grapefruit            Positive, Positive
# 4                           price                      Positive
# ..                            ...                           ...
# 95
# 96                      use, lips            Positive, Positive
# 97                  laneige, lips            Positive, Positive
# 98                     applicator                      Negative
# 99                    application                      Negative
#
# [100 rows x 2 columns]

# %%
product_reviews_df_process.to_csv('product_processed.csv')
